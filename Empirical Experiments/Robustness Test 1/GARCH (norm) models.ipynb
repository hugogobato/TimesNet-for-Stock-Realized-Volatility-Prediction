# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Median

# %%
df=pd.read_excel("SP100_return.xlsx",index_col='Date',parse_dates=True)

# %%
df.head()
# Out:
#                  AMT       COP       CVX       AXP       BAC         C  \
# Date
# 2007-06-27  0.022206  0.026145  0.017326  0.002358  0.006628  0.015845
# 2007-06-28  0.000654 -0.007271  0.000119 -0.004419 -0.003862 -0.003659
# 2007-06-29  0.005251  0.017117 -0.003907 -0.001960 -0.009981 -0.012791
# 2007-07-02  0.021480  0.017496  0.009938  0.010241  0.005082  0.005336
# 2007-07-06  0.017532 -0.002464  0.007031 -0.000106 -0.004873 -0.000870
#
#                   CB       CME        GS       JPM  ...       TMO       UNH  \
# Date                                                ...
# 2007-06-27 -0.004513  0.020549  0.024320  0.016685  ...  0.031496  0.001353
# 2007-06-28 -0.006281  0.004153 -0.001186 -0.005399  ... -0.004642  0.010810
# 2007-06-29  0.002611 -0.019107 -0.016688 -0.014768  ...  0.004057 -0.020300
# 2007-07-02  0.008172 -0.003010  0.009246  0.012969  ...  0.009049  0.009202
# 2007-07-06 -0.001978  0.049970  0.012025  0.003782  ... -0.004655  0.012623
#
#                 AMZN        HD       LOW       MCD       NKE      SBUX  \
# Date
# 2007-06-27  0.016792  0.019041  0.003240 -0.005927  0.030739  0.017758
# 2007-06-28  0.008082 -0.005047 -0.017265 -0.010955 -0.002375 -0.002267
# 2007-06-29 -0.009889 -0.008725 -0.002929 -0.001812 -0.001492 -0.012114
# 2007-07-02  0.012580  0.000254 -0.003249  0.009388 -0.001368 -0.015622
# 2007-07-06  0.003414  0.015115  0.010015  0.005651  0.004135  0.005477
#
#                  TGT       TJX
# Date
# 2007-06-27  0.009618  0.028079
# 2007-06-28  0.001103  0.004593
# 2007-06-29 -0.001248 -0.008891
# 2007-07-02  0.008715 -0.001862
# 2007-07-06  0.057232  0.008365
#
# [5 rows x 80 columns]

# %%
returns=df*100

# %%
# !pip install arch
# Out:
# Collecting arch
#   Downloading arch-6.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.7/981.7 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.10/dist-packages (from arch) (1.23.5)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.10/dist-packages (from arch) (1.11.3)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.10/dist-packages (from arch) (1.5.3)
# Requirement already satisfied: statsmodels>=0.12 in /usr/local/lib/python3.10/dist-packages (from arch) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->arch) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->arch) (2023.3.post1)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.12->arch) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.12->arch) (23.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels>=0.12->arch) (1.16.0)
# Installing collected packages: arch
# Successfully installed arch-6.2.0

# %%
from arch import arch_model

# %%
df1=pd.read_excel("SP100_vol.xlsx",index_col='Date',parse_dates=True, sheet_name="SP100 Original")

# %%
df1.iloc[int(len(df1)*0.8)]
# Out:
# AMT     0.006287
# COP     0.011492
# CVX     0.007431
# AXP     0.006722
# BAC     0.007536
#           ...
# MCD     0.004273
# NKE     0.009057
# SBUX    0.007809
# TGT     0.007861
# TJX     0.007815
# Name: 2018-08-30 00:00:00, Length: 80, dtype: float64

# %%
forecasts1=np.zeros([int(len(df1)*0.2),len(df.columns)])
test_size = int(len(df1)*0.2)
for i in range(len(df.columns)):
  am = arch_model(returns[df.columns[i]], vol="garch", p=1, o=0, q=1, dist="Normal")
  res = am.fit(update_freq=5,last_obs="2018-08-30")
  rolling_predictions = []
  for j in range(int(test_size/1)):
    train = returns[:-(test_size-j*1)]
    model = arch_model(train[df.columns[i]], p=1, o=0, q=1)
    model_fit = model.fit(disp='off')
    pred = model_fit.forecast(horizon=1)
    rolling_predictions.append(np.sqrt(pred.variance.values[-1,:]))
  rolling_predictions=np.sqrt(rolling_predictions)**2
  rolling_predictions=rolling_predictions.reshape(forecasts1.shape[0])
  forecasts1[:,i]=rolling_predictions/100
# Out:
# Iteration:      5,   Func. Count:     37,   Neg. LLF: 4602.425755609685
# Iteration:     10,   Func. Count:     67,   Neg. LLF: 4560.603445254462
# Iteration:     15,   Func. Count:     92,   Neg. LLF: 4560.543392763269
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4560.543392763269
#             Iterations: 16
#             Function evaluations: 96
#             Gradient evaluations: 16
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 4793.82144708528
# Iteration:     10,   Func. Count:     63,   Neg. LLF: 4780.749437208492
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4780.619699167143
#             Iterations: 14
#             Function evaluations: 84
#             Gradient evaluations: 14
# Iteration:      5,   Func. Count:     35,   Neg. LLF: 4144.789369010779
# Iteration:     10,   Func. Count:     63,   Neg. LLF: 4136.309859500901
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4136.309859500901
#             Iterations: 11
#             Function evaluations: 67
#             Gradient evaluations: 11
# Iteration:      5,   Func. Count:     35,   Neg. LLF: 6964.714883680437
# Iteration:     10,   Func. Count:     65,   Neg. LLF: 4748.257081449723
# Iteration:     15,   Func. Count:     91,   Neg. LLF: 4747.008296147365
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4747.008296147365
#             Iterations: 16
#             Function evaluations: 95
#             Gradient evaluations: 16
# Iteration:      5,   Func. Count:     35,   Neg. LLF: 19066.740497192917
# Iteration:     10,   Func. Count:     65,   Neg. LLF: 5439.7280970714855
# Iteration:     15,   Func. Count:     89,   Neg. LLF: 5439.708161800212
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5439.708161800681
#             Iterations: 15
#             Function evaluations: 89
#             Gradient evaluations: 15
# Iteration:      5,   Func. Count:     35,   Neg. LLF: 777031332.390834
# Iteration:     10,   Func. Count:     65,   Neg. LLF: 6026.615429527841
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5361.908128107331
#             Iterations: 14
#             Function evaluations: 88
#             Gradient evaluations: 14
# Iteration:      5,   Func. Count:     35,   Neg. LLF: 3997.0320887032667
# Iteration:     10,   Func. Count:     63,   Neg. LLF: 3923.0173280673093
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3923.0173280673093
#             Iterations: 11
#             Function evaluations: 67
#             Gradient evaluations: 11
# Iteration:      5,   Func. Count:     34,   Neg. LLF: 457734480.84725267
# Iteration:     10,   Func. Count:     62,   Neg. LLF: 5055.915204556019
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5055.915189096867
#             Iterations: 12
#             Function evaluations: 71
#             Gradient evaluations: 12
# Iteration:      5,   Func. Count:     34,   Neg. LLF: 5040.217274716893
# Iteration:     10,   Func. Count:     63,   Neg. LLF: 4979.165081412477
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4979.1648491526375
#             Iterations: 13
#             Function evaluations: 78
#             Gradient evaluations: 13
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 1244923170.5765567
# Iteration:     10,   Func. Count:     67,   Neg. LLF: 4915.2335985821555
# Iteration:     15,   Func. Count:     92,   Neg. LLF: 4914.471884937108
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4914.471884936838
#             Iterations: 15
#             Function evaluations: 92
#             Gradient evaluations: 15
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 5649.150944757069
# Iteration:     10,   Func. Count:     66,   Neg. LLF: 5609.216677435124
# Iteration:     15,   Func. Count:     93,   Neg. LLF: 5606.498183961321
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5606.498179954955
#             Iterations: 17
#             Function evaluations: 102
#             Gradient evaluations: 17
# Iteration:      5,   Func. Count:     35,   Neg. LLF: 950979934.034056
# Iteration:     10,   Func. Count:     65,   Neg. LLF: 4946.1533537924815
# Iteration:     15,   Func. Count:     92,   Neg. LLF: 4942.61518632891
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4942.61518632891
#             Iterations: 15
#             Function evaluations: 92
#             Gradient evaluations: 15
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 7632.47429683965
# Iteration:     10,   Func. Count:     62,   Neg. LLF: 4555.391616766947
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4555.3916001947355
#             Iterations: 12
#             Function evaluations: 71
#             Gradient evaluations: 12
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 4919.060898725379
# Iteration:     10,   Func. Count:     63,   Neg. LLF: 4888.372299129433
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4888.341052524077
#             Iterations: 13
#             Function evaluations: 78
#             Gradient evaluations: 13
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 4660.337423347659
# Iteration:     10,   Func. Count:     64,   Neg. LLF: 4599.187314766961
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4599.187312663898
#             Iterations: 12
#             Function evaluations: 73
#             Gradient evaluations: 12
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 7043.992245012593
# Iteration:     10,   Func. Count:     64,   Neg. LLF: 4793.661578853813
# Iteration:     15,   Func. Count:     90,   Neg. LLF: 4790.044556291047
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4790.044556291047
#             Iterations: 16
#             Function evaluations: 94
#             Gradient evaluations: 16
# Iteration:      5,   Func. Count:     35,   Neg. LLF: 4436.522483911473
# Iteration:     10,   Func. Count:     63,   Neg. LLF: 4416.890103638762
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4416.890103638762
#             Iterations: 11
#             Function evaluations: 67
#             Gradient evaluations: 11
# Iteration:      5,   Func. Count:     35,   Neg. LLF: 4138.9803301694155
# Iteration:     10,   Func. Count:     64,   Neg. LLF: 4135.697153447862
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4135.697153447862
#             Iterations: 11
#             Function evaluations: 68
#             Gradient evaluations: 11
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 4128.993629832741
# Iteration:     10,   Func. Count:     64,   Neg. LLF: 4103.523109370078
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4103.523107935051
#             Iterations: 12
#             Function evaluations: 73
#             Gradient evaluations: 12
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 3822.2439405151754
# Iteration:     10,   Func. Count:     63,   Neg. LLF: 3788.075366621745
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3787.312076681639
#             Iterations: 13
#             Function evaluations: 78
#             Gradient evaluations: 13
# Iteration:      5,   Func. Count:     35,   Neg. LLF: 5321.923429126331
# Iteration:     10,   Func. Count:     66,   Neg. LLF: 4724.630411443344
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4724.629070143341
#             Iterations: 13
#             Function evaluations: 80
#             Gradient evaluations: 13
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 3769.2584073761836
# Iteration:     10,   Func. Count:     61,   Neg. LLF: 3765.2434044963634
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3765.2434044973684
#             Iterations: 10
#             Function evaluations: 61
#             Gradient evaluations: 10
# Iteration:      5,   Func. Count:     35,   Neg. LLF: 4730.701792064775
# Iteration:     10,   Func. Count:     62,   Neg. LLF: 4722.259202607915
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4722.259171583555
#             Iterations: 13
#             Function evaluations: 76
#             Gradient evaluations: 13
# Iteration:      5,   Func. Count:     36,   Neg. LLF:
# Iteration:     10,   Func. Count:     64,   Neg. LLF: 4486.890609630912
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4486.890607839563
#             Iterations: 12
#             Function evaluations: 73
#             Gradient evaluations: 12
# Iteration:      5,   Func. Count:     38,   Neg. LLF: 3882.0346869051837
# Iteration:     10,   Func. Count:     64,   Neg. LLF: 3854.5842644611403
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3854.5842644611403
#             Iterations: 10
#             Function evaluations: 64
#             Gradient evaluations: 10
# Iteration:      5,   Func. Count:     37,   Neg. LLF: 5370.452250983174
# Iteration:     10,   Func. Count:     64,   Neg. LLF: 4322.229881984789
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4322.229880117502
#             Iterations: 12
#             Function evaluations: 73
#             Gradient evaluations: 12
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 5215.3960596140005
# Iteration:     10,   Func. Count:     65,   Neg. LLF: 5198.2252565952385
# Iteration:     15,   Func. Count:     90,   Neg. LLF: 5198.21274383376
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5198.212743833933
#             Iterations: 15
#             Function evaluations: 90
#             Gradient evaluations: 15
# Iteration:      5,   Func. Count:     38,   Neg. LLF: 5304.921802230504
# Iteration:     10,   Func. Count:     68,   Neg. LLF: 5126.0314203795515
# Iteration:     15,   Func. Count:     94,   Neg. LLF: 5125.983292251485
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5125.983289239575
#             Iterations: 17
#             Function evaluations: 103
#             Gradient evaluations: 17
# Iteration:      5,   Func. Count:     37,   Neg. LLF: 4377.70820525921
# Iteration:     10,   Func. Count:     66,   Neg. LLF: 4306.566512124554
# Iteration:     15,   Func. Count:     90,   Neg. LLF: 4306.566272524446
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4306.566272527649
#             Iterations: 15
#             Function evaluations: 90
#             Gradient evaluations: 15
# Iteration:      5,   Func. Count:     37,   Neg. LLF: 4060.7343290631084
# Iteration:     10,   Func. Count:     64,   Neg. LLF: 4049.880904395809
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4049.8808872833106
#             Iterations: 13
#             Function evaluations: 78
#             Gradient evaluations: 13
# Iteration:      5,   Func. Count:     38,   Neg. LLF: 4838.210435415915
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4838.195407948615
#             Iterations: 9
#             Function evaluations: 57
#             Gradient evaluations: 9
# Iteration:      5,   Func. Count:     35,   Neg. LLF: 11028.895724015643
# Iteration:     10,   Func. Count:     63,   Neg. LLF: 5222.056414160667
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5222.056413518809
#             Iterations: 11
#             Function evaluations: 68
#             Gradient evaluations: 11
# Iteration:      5,   Func. Count:     40,   Neg. LLF: 3117.351036613233
# Iteration:     10,   Func. Count:     64,   Neg. LLF: 3117.3397410522593
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3117.3397410516536
#             Iterations: 10
#             Function evaluations: 64
#             Gradient evaluations: 10
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 4517.863448780127
# Iteration:     10,   Func. Count:     63,   Neg. LLF: 4104.001463349964
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4104.001463349964
#             Iterations: 11
#             Function evaluations: 67
#             Gradient evaluations: 11
# Iteration:      5,   Func. Count:     37,   Neg. LLF: 4187.052558896708
# Iteration:     10,   Func. Count:     63,   Neg. LLF: 4168.455548289676
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4168.45554601754
#             Iterations: 12
#             Function evaluations: 72
#             Gradient evaluations: 12
# Iteration:      5,   Func. Count:     37,   Neg. LLF: 4107.063947890267
# Iteration:     10,   Func. Count:     62,   Neg. LLF: 4098.079257078343
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4098.07925707541
#             Iterations: 10
#             Function evaluations: 62
#             Gradient evaluations: 10
# Iteration:      5,   Func. Count:     38,   Neg. LLF: 3957.2385928721264
# Iteration:     10,   Func. Count:     63,   Neg. LLF: 3936.44641333899
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3936.4464133388296
#             Iterations: 10
#             Function evaluations: 63
#             Gradient evaluations: 10
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 4756.213943947909
# Iteration:     10,   Func. Count:     63,   Neg. LLF: 4203.995635351814
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4203.995605441433
#             Iterations: 13
#             Function evaluations: 77
#             Gradient evaluations: 13
# Iteration:      5,   Func. Count:     35,   Neg. LLF: 5119.772491725105
# Iteration:     10,   Func. Count:     62,   Neg. LLF: 4386.477225976342
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4386.477214570263
#             Iterations: 12
#             Function evaluations: 71
#             Gradient evaluations: 12
# Iteration:      5,   Func. Count:     34,   Neg. LLF: 4717.349777128358
# Iteration:     10,   Func. Count:     64,   Neg. LLF: 4706.172789619384
# Iteration:     15,   Func. Count:     89,   Neg. LLF: 4706.155698386943
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4706.155698384462
#             Iterations: 15
#             Function evaluations: 89
#             Gradient evaluations: 15
# Iteration:      5,   Func. Count:     35,   Neg. LLF: 12295229.82422866
# Iteration:     10,   Func. Count:     65,   Neg. LLF: 5192.284959668152
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5191.665638572966
#             Iterations: 14
#             Function evaluations: 85
#             Gradient evaluations: 14
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 8039.453240129505
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4364.381442515454
#             Iterations: 9
#             Function evaluations: 58
#             Gradient evaluations: 9
# Iteration:      5,   Func. Count:     38,   Neg. LLF: 5672.697635524768
# Iteration:     10,   Func. Count:     66,   Neg. LLF: 4892.775669509683
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4892.775669509683
#             Iterations: 11
#             Function evaluations: 70
#             Gradient evaluations: 11
# Iteration:      5,   Func. Count:     38,   Neg. LLF: 3572.913758154593
# Iteration:     10,   Func. Count:     65,   Neg. LLF: 3477.526924887233
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3477.526924426836
#             Iterations: 11
#             Function evaluations: 70
#             Gradient evaluations: 11
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 1108558292.2415712
# Iteration:     10,   Func. Count:     65,   Neg. LLF: 4463.799964563557
# Iteration:     15,   Func. Count:     91,   Neg. LLF: 4463.791241108389
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4463.791241108389
#             Iterations: 15
#             Function evaluations: 91
#             Gradient evaluations: 15
# Iteration:      5,   Func. Count:     34,   Neg. LLF: 4721.6693603279
# Iteration:     10,   Func. Count:     64,   Neg. LLF: 4695.42516666936
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4695.42516406659
#             Iterations: 12
#             Function evaluations: 73
#             Gradient evaluations: 12
# Iteration:      5,   Func. Count:     34,   Neg. LLF: 4662.16044337737
# Iteration:     10,   Func. Count:     64,   Neg. LLF: 4611.348786543769
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4611.177960623634
#             Iterations: 14
#             Function evaluations: 86
#             Gradient evaluations: 14
# Iteration:      5,   Func. Count:     37,   Neg. LLF: 22799.413052673062
# Iteration:     10,   Func. Count:     66,   Neg. LLF: 4566.921384269595
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 4566.916994648971
#             Iterations: 14
#             Function evaluations: 85
#             Gradient evaluations: 14

# %%
df2=df1.iloc[int(len(df1)*0.8)+1:len(df1)]

# %%
for i in range(len(df2.columns)):
  df2[df2.columns[i]]=forecasts1[:,i]
# Out:
# <ipython-input-11-ae522ed45476>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[df2.columns[i]]=forecasts1[:,i]

# %%
df2.to_excel("GARCH(1,1)-Norm forecasts.xlsx")
